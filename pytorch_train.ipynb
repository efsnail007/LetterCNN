# %%
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
from torchvision import datasets, transforms
import torchvision.transforms as transforms
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import MultiStepLR

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)


class LetterCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5)

        self.fc1 = nn.Linear(in_features=16 * 5 * 5, out_features=120)
        self.fc2 = nn.Linear(in_features=120, out_features=84)
        self.out = nn.Linear(in_features=84, out_features=3)

    def forward(self, t):
        t = self.conv1(t)
        t = F.relu(t)
        t = F.max_pool2d(t, kernel_size=2, stride=2)
        # torch.Size([1, 6, 14, 14])

        t = self.conv2(t)
        t = F.relu(t)
        t = F.max_pool2d(t, kernel_size=2, stride=2)
        # torch.Size([1, 16, 5, 5])

        t = t.reshape(-1, 16 * 5 * 5)
        t = self.fc1(t)
        t = F.relu(t)
        # torch.Size([1, 120])

        t = self.fc2(t)
        t = F.relu(t)
        # torch.Size([1, 84])

        t = self.out(t)
        # torch.Size([1, 3])
        return t
# Out:
# Device: cuda

# %%
mean = (0.5, 0.5, 0.5)
std = (0.5, 0.5, 0.5)

train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomRotation(10),
    transforms.RandomAffine(
        degrees=0,
        translate=(0.1, 0.1),
    ),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

train_set = datasets.ImageFolder(
    root="data/train",
    transform=train_transform,
)

test_set = datasets.ImageFolder(
    root="data/test",
    transform=test_transform,
)

train_loader = DataLoader(
    dataset=train_set,
    batch_size=10,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
)

test_loader = DataLoader(
    dataset=test_set,
    batch_size=10,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
)

print(train_set.classes)
print(test_set.classes)
# Out:
# ['p', 'sh', 't']
# ['p', 'sh', 't']

# %%
model = LetterCNN().to(device)
torch.save(model.state_dict(), "init_state.pth")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(
    model.parameters(),
    lr=1e-3,
    weight_decay=1e-4
)
scheduler = optim.lr_scheduler.MultiStepLR(
    optimizer,
    milestones=[20, 40],
    gamma=0.1
)

num_epochs = 60
best_acc = 0.0


@torch.no_grad()
def evaluate(model, data_loader, device):
    model.eval()
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in data_loader:
        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        outputs = model(images)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * images.size(0)
        _, preds = outputs.max(1)
        correct += preds.eq(labels).sum().item()
        total += labels.size(0)

    avg_loss = running_loss / total
    acc = correct / total
    return avg_loss, acc

# %%
for epoch in range(1, num_epochs + 1):
    model.train()
    running_loss = 0.0
    total = 0
    correct = 0

    for images, labels in train_loader:
        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        total += labels.size(0)
        _, preds = outputs.max(1)
        correct += preds.eq(labels).sum().item()

    train_loss = running_loss / total
    train_acc = correct / total

    val_loss, val_acc = evaluate(model, test_loader, device)
    scheduler.step()

    print(
        f"Epoch [{epoch}/{num_epochs}] "
        f"train_loss={train_loss:.4f} train_acc={train_acc:.4f} "
        f"val_loss={val_loss:.4f} val_acc={val_acc:.4f} "
        f"lr={scheduler.get_last_lr()[0]:.5f}"
    )

    if val_acc > best_acc:
        best_acc = val_acc
        torch.save(model.state_dict(), "best.pth")
        print(f"  -> new best model saved (val_acc={best_acc:.4f})")
# Out:
# Epoch [1/60] train_loss=1.0979 train_acc=0.3498 val_loss=1.0809 val_acc=0.5155 lr=0.00100
#   -> new best model saved (val_acc=0.5155)
# Epoch [2/60] train_loss=1.0302 train_acc=0.4593 val_loss=1.0148 val_acc=0.5271 lr=0.00100
#   -> new best model saved (val_acc=0.5271)
# Epoch [3/60] train_loss=0.9278 train_acc=0.5523 val_loss=0.8280 val_acc=0.6163 lr=0.00100
#   -> new best model saved (val_acc=0.6163)
# Epoch [4/60] train_loss=0.7522 train_acc=0.6512 val_loss=0.6040 val_acc=0.7636 lr=0.00100
#   -> new best model saved (val_acc=0.7636)
# Epoch [5/60] train_loss=0.6404 train_acc=0.7141 val_loss=0.5069 val_acc=0.7907 lr=0.00100
#   -> new best model saved (val_acc=0.7907)
# Epoch [6/60] train_loss=0.5645 train_acc=0.7636 val_loss=0.4047 val_acc=0.8411 lr=0.00100
#   -> new best model saved (val_acc=0.8411)
# Epoch [7/60] train_loss=0.4884 train_acc=0.8052 val_loss=0.3838 val_acc=0.8333 lr=0.00100
# Epoch [8/60] train_loss=0.4123 train_acc=0.8488 val_loss=0.3700 val_acc=0.8372 lr=0.00100
# Epoch [9/60] train_loss=0.4090 train_acc=0.8450 val_loss=0.2907 val_acc=0.8837 lr=0.00100
#   -> new best model saved (val_acc=0.8837)
# Epoch [10/60] train_loss=0.3667 train_acc=0.8624 val_loss=0.3372 val_acc=0.8721 lr=0.00100
# Epoch [11/60] train_loss=0.3401 train_acc=0.8692 val_loss=0.3459 val_acc=0.8643 lr=0.00100
# Epoch [12/60] train_loss=0.3611 train_acc=0.8566 val_loss=0.3122 val_acc=0.8953 lr=0.00100
#   -> new best model saved (val_acc=0.8953)
# Epoch [13/60] train_loss=0.3189 train_acc=0.8808 val_loss=0.3177 val_acc=0.8682 lr=0.00100
# Epoch [14/60] train_loss=0.3208 train_acc=0.8711 val_loss=0.3089 val_acc=0.8876 lr=0.00100
# Epoch [15/60] train_loss=0.3030 train_acc=0.8808 val_loss=0.2395 val_acc=0.9109 lr=0.00100
#   -> new best model saved (val_acc=0.9109)
# Epoch [16/60] train_loss=0.2937 train_acc=0.8876 val_loss=0.3473 val_acc=0.8411 lr=0.00100
# Epoch [17/60] train_loss=0.2816 train_acc=0.8895 val_loss=0.2485 val_acc=0.8992 lr=0.00100
# Epoch [18/60] train_loss=0.2499 train_acc=0.8992 val_loss=0.2641 val_acc=0.8798 lr=0.00100
# Epoch [19/60] train_loss=0.2593 train_acc=0.8963 val_loss=0.2313 val_acc=0.8915 lr=0.00100
# Epoch [20/60] train_loss=0.2695 train_acc=0.9012 val_loss=0.2876 val_acc=0.8760 lr=0.00010
# Epoch [21/60] train_loss=0.2137 train_acc=0.9215 val_loss=0.2114 val_acc=0.9109 lr=0.00010
# Epoch [22/60] train_loss=0.1832 train_acc=0.9390 val_loss=0.2059 val_acc=0.9109 lr=0.00010
# Epoch [23/60] train_loss=0.1804 train_acc=0.9302 val_loss=0.1986 val_acc=0.9186 lr=0.00010
#   -> new best model saved (val_acc=0.9186)
# Epoch [24/60] train_loss=0.1754 train_acc=0.9370 val_loss=0.1947 val_acc=0.9186 lr=0.00010
# Epoch [25/60] train_loss=0.1662 train_acc=0.9370 val_loss=0.1937 val_acc=0.9109 lr=0.00010
# Epoch [26/60] train_loss=0.1714 train_acc=0.9322 val_loss=0.1813 val_acc=0.9264 lr=0.00010
#   -> new best model saved (val_acc=0.9264)
# Epoch [27/60] train_loss=0.1684 train_acc=0.9390 val_loss=0.1958 val_acc=0.9109 lr=0.00010
# Epoch [28/60] train_loss=0.1492 train_acc=0.9457 val_loss=0.1810 val_acc=0.9264 lr=0.00010
# Epoch [29/60] train_loss=0.1808 train_acc=0.9409 val_loss=0.1768 val_acc=0.9186 lr=0.00010
# Epoch [30/60] train_loss=0.1666 train_acc=0.9448 val_loss=0.1815 val_acc=0.9225 lr=0.00010
# Epoch [31/60] train_loss=0.1611 train_acc=0.9370 val_loss=0.1839 val_acc=0.9147 lr=0.00010
# Epoch [32/60] train_loss=0.1618 train_acc=0.9380 val_loss=0.1874 val_acc=0.9147 lr=0.00010
# Epoch [33/60] train_loss=0.1634 train_acc=0.9419 val_loss=0.1676 val_acc=0.9264 lr=0.00010
# Epoch [34/60] train_loss=0.1490 train_acc=0.9525 val_loss=0.1655 val_acc=0.9225 lr=0.00010
# Epoch [35/60] train_loss=0.1552 train_acc=0.9399 val_loss=0.1704 val_acc=0.9264 lr=0.00010
# Epoch [36/60] train_loss=0.1575 train_acc=0.9448 val_loss=0.1754 val_acc=0.9264 lr=0.00010
# Epoch [37/60] train_loss=0.1426 train_acc=0.9496 val_loss=0.1743 val_acc=0.9147 lr=0.00010
# Epoch [38/60] train_loss=0.1527 train_acc=0.9399 val_loss=0.1701 val_acc=0.9264 lr=0.00010
# Epoch [39/60] train_loss=0.1552 train_acc=0.9477 val_loss=0.1688 val_acc=0.9186 lr=0.00010
# Epoch [40/60] train_loss=0.1320 train_acc=0.9564 val_loss=0.1592 val_acc=0.9302 lr=0.00001
#   -> new best model saved (val_acc=0.9302)
# Epoch [41/60] train_loss=0.1384 train_acc=0.9467 val_loss=0.1570 val_acc=0.9264 lr=0.00001
# Epoch [42/60] train_loss=0.1558 train_acc=0.9467 val_loss=0.1562 val_acc=0.9264 lr=0.00001
# Epoch [43/60] train_loss=0.1358 train_acc=0.9593 val_loss=0.1592 val_acc=0.9302 lr=0.00001
# Epoch [44/60] train_loss=0.1522 train_acc=0.9477 val_loss=0.1585 val_acc=0.9264 lr=0.00001
# Epoch [45/60] train_loss=0.1316 train_acc=0.9545 val_loss=0.1594 val_acc=0.9264 lr=0.00001
# Epoch [46/60] train_loss=0.1351 train_acc=0.9554 val_loss=0.1594 val_acc=0.9264 lr=0.00001
# Epoch [47/60] train_loss=0.1466 train_acc=0.9428 val_loss=0.1607 val_acc=0.9225 lr=0.00001
# Epoch [48/60] train_loss=0.1403 train_acc=0.9457 val_loss=0.1598 val_acc=0.9264 lr=0.00001
# Epoch [49/60] train_loss=0.1371 train_acc=0.9535 val_loss=0.1588 val_acc=0.9264 lr=0.00001
# Epoch [50/60] train_loss=0.1522 train_acc=0.9448 val_loss=0.1594 val_acc=0.9264 lr=0.00001
# Epoch [51/60] train_loss=0.1471 train_acc=0.9419 val_loss=0.1599 val_acc=0.9264 lr=0.00001
# Epoch [52/60] train_loss=0.1414 train_acc=0.9467 val_loss=0.1606 val_acc=0.9225 lr=0.00001
# Epoch [53/60] train_loss=0.1380 train_acc=0.9438 val_loss=0.1602 val_acc=0.9264 lr=0.00001
# Epoch [54/60] train_loss=0.1404 train_acc=0.9399 val_loss=0.1604 val_acc=0.9302 lr=0.00001
# Epoch [55/60] train_loss=0.1262 train_acc=0.9564 val_loss=0.1593 val_acc=0.9302 lr=0.00001
# Epoch [56/60] train_loss=0.1447 train_acc=0.9486 val_loss=0.1591 val_acc=0.9302 lr=0.00001
# Epoch [57/60] train_loss=0.1338 train_acc=0.9525 val_loss=0.1597 val_acc=0.9302 lr=0.00001
# Epoch [58/60] train_loss=0.1346 train_acc=0.9477 val_loss=0.1593 val_acc=0.9302 lr=0.00001
# Epoch [59/60] train_loss=0.1407 train_acc=0.9516 val_loss=0.1598 val_acc=0.9264 lr=0.00001
# Epoch [60/60] train_loss=0.1367 train_acc=0.9486 val_loss=0.1607 val_acc=0.9264 lr=0.00001
